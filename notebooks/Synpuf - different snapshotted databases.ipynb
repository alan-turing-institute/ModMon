# %% [markdown]
# Driver obtained on Mac with the following: https://docs.microsoft.com/en-us/sql/connect/odbc/linux-mac/install-microsoft-odbc-driver-sql-server-macos?view=sql-server-ver15#microsoft-odbc-17

# %%
import pandas as pd
import pyodbc
driver = "/usr/local/lib/libmsodbcsql.17.dylib"
cnxn_string = 'Driver={' + driver + '};Server=51.104.224.106,1433;Database=WEEK_X;UID=analysts;PWD=An8lysts.'

# %%
def get_cnxn(n):
    c_str = cnxn_string.replace("X", "{0:0=2d}".format(n))
    return pyodbc.connect(c_str)

# %%
pd.read_sql('SELECT * FROM person;', get_cnxn(1)).head()
# Out:
#    person_id  gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# 0          1               8507           1923               5             1
# 1          2               8507           1943               1             1
# 2          3               8532           1936               9             1
# 3          4               8507           1941               6             1
# 4          5               8507           1936               8             1
#
#   birth_datetime  race_concept_id  ethnicity_concept_id  location_id  \
# 0           None             8527              38003564            1
# 1           None             8527              38003564            2
# 2           None             8527              38003564            3
# 3           None                0              38003563            4
# 4           None             8527              38003564            5
#
#   provider_id care_site_id person_source_value gender_source_value  \
# ...

# %%
pd.read_sql('SELECT * FROM person;', get_cnxn(10)).head()
# Out:
#    person_id  gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# 0          1               8507           1923               5             1
# 1          2               8507           1943               1             1
# 2          3               8532           1936               9             1
# 3          4               8507           1941               6             1
# 4          5               8507           1936               8             1
#
#   birth_datetime  race_concept_id  ethnicity_concept_id  location_id  \
# 0           None             8527              38003564            1
# 1           None             8527              38003564            2
# 2           None             8527              38003564            3
# 3           None                0              38003563            4
# 4           None             8527              38003564            5
#
#   provider_id care_site_id person_source_value gender_source_value  \
# ...

# %%
pd.read_sql("SELECT COUNT(person_id) AS person_count FROM person", get_cnxn(1))["person_count"][0]
# Out:
# 200

# %%
pd.read_sql("SELECT COUNT(person_id) FROM person", get_cnxn(10))
# Out:
#
# 0  1000

# %%
person = pd.read_sql("SELECT * FROM person;", get_cnxn(10))
year_counts = person.groupby("year_of_birth").count().person_id
born_83 = year_counts[1960]
born_83
# Out:
# 7
